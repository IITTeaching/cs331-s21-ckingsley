# %% [markdown]
# The Array-Backed List
# =====================

# %% [markdown]
# ## Agenda

# %% [markdown]
# 1.  The List **Abstract Data Type** (ADT)
# 2.  A List **Data Structure**
# 3.  Our List API
# 4.  Getting started: how to store our data?
# 5.  Built-in `list` as array
# 6.  The `ArrayList` data structure

# %% [markdown]
# ## 1.  The List **Abstract Data Type** (ADT)

# %% [markdown]
# An **abstract data type (ADT)** defines a *conceptual model* for how data
# may be stored and accessed.
#
# A **list ADT** is a data container where:
#
# -   values are ordered in a *sequence*
# -   each value has at most one preceding and one succeeding value
# -   a given value may appear more than once in a list
#
# Other common ADTs (some of which we'll explore later) include:
#
# -   Stacks
# -   Queues
# -   Priority Queues
# -   Maps
# -   Graphs

# %% [markdown]
# ## 1.  A List **Data Structure**

# %% [markdown]
# A **list data structure** is a *concrete implementation* of the list ADT
# in some programming language, which, in addition to adhering to the
# basic premises of the ADT, will also typically support operations that:
#
# -   access values in the list by their position (index)
# -   append and insert new values into the list
# -   remove values from the list
#
# The implementation of any data structure will generally rely on simpler,
# constituent data types (e.g., "primitive" types offered by the
# language), the choice of which may affect the runtime complexities of
# said operations.

# %% [markdown]
# ## 1.  The List API

# %% [markdown]
# The operations we'll be building into our list data structures will be
# based on the
# [common](https://docs.python.org/3.6/library/stdtypes.html#common-sequence-operations)
# and
# [mutable](https://docs.python.org/3.6/library/stdtypes.html#mutable-sequence-types)
# sequence operations defined by the Python library.

# %%
class List:
    ### subscript-based access ###


    # idx is index
    def __getitem__(self, idx):
        """Implements `x = self[idx]`"""
        pass


    def __setitem__(self, idx, value):
        """Implements `self[idx] = x`"""
        pass

    def __delitem__(self, idx):
        """Implements `del self[idx]`"""
        pass

    ### stringification ###

    def __repr__(self):
        """Supports inspection"""
        return '[]'

    def __str__(self):
        """Implements `str(self)`"""
        return '[]'

    ### single-element manipulation ###

    def append(self, value):
        pass

    def insert(self, idx, value):
        pass

    def pop(self, idx=-1):
        pass

    def remove(self, value):
        pass

    ### predicates (T/F queries) ###

    def __eq__(self, other):
        """Implements `self == other`"""
        return True

    def __contains__(self, value):
        """Implements `value in self`"""
        return True

    ### queries ###

    def __len__(self):
        """Implements `len(self)`"""
        return len(self.data)

    def min(self):
        pass

    def max(self):
        pass

        #first occurance of value between i and j
    def index(self, value, i, j):
        pass

    def count(self, value):
        pass

    ### bulk operations ###

    #add another sequence to end of sequence
    def __add__(self, other):
        """Implements `self + other_array_list`"""
        return self

    def clear(self):
        pass

    def copy(self):
        pass

    def extend(self, other):
        pass

    ### iteration ###

    def __iter__(self):
        """Supports iteration (via `iter(self)`)"""
        pass

# %% [markdown]
# ## 1.  Getting started: how to store our data?

# %%
class List:
    def ini():
        pass

    def append(self, value):
        pass

    def __getitem__(self, idx):
        """Implements `x = self[idx]`"""
        pass

    def __setitem__(self, idx, value):
        """Implements `self[idx] = x`"""
        pass

    def __repr__(self):
        """Supports inspection"""
        pass

# %% [markdown]
# ## 1.  Built-in `list` as array

# %% [markdown]
# To use the built-in list as though it were a primitive array, we will
# constrain ourselves to just the following APIs on a given list `lst`:
#
# 1.  `lst[i]` for getting and setting values at an *existing, positive*
#     index `i`
# 2.  `len(lst)` to obtain the number of slots
# 3.  `lst.append(None)` to grow the list by *one slot at a time*
# 4.  `del lst[len(lst)-1]` to delete the last slot in a list

# %% [markdown]
# ## 1.  The `ArrayList` data structure

# %%
class MyArrayList:
    def __init__(self,n=1):
        self.data = MyArray(n)

    def append(self, value):
        self.data.append(value)

    def __getitem__(self, idx):
        """Implements `x = self[idx]`"""
        assert(isinstance(idx, int))
        return self.data[idx]

    def __setitem__(self, idx, value):
        """Implements `self[idx] = x`"""
        assert(isinstance(idx, int))
        self.data[idx] = value

    def __delitem__(self, idx):
        """Implements `del self[idx]`"""
        assert(isinstance(idx, int))
        for i in range(idx+1, len(self.data)):
            self.data[i-1] = self.data[i] #shifting elements to the left
        del self.data[len(self.data)-1] #get rid of last element
        

    def __len__(self):
        """Implements `len(self)`"""
        len(self.data)

    def __repr__(self):
        """Supports inspection"""
        return "[" + ",".join([str(x) for x in self.data]) + "]"

# %%
x = MyArrayList()
x.append(1)
x.append(2)
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-52f3eb01cbe1> in <module>
# ----> 1 x = MyArrayList()
#       2 x.append(1)
#       3 x.append(2)
#       4 x
#
# <ipython-input-16-4a39ebf219d5> in __init__(self, n)
#       1 class MyArrayList:
#       2     def __init__(self,n=1):
# ----> 3         self.data = MyArray(n)
#       4
#       5     def append(self, value):
#
# NameError: name 'MyArray' is not defined

# %% [markdown]
#     [1,2]

# %%
y = MyArrayList()
y.append(1)
y.append(3)
y.append(4)
y
del(y[2])

# %% [markdown]
#     [1,3,4]

# %%
*Array API*
- create array of size n
- access element at poisition i
- set the element at position i
- get length of an array
# Out:
#   File "<ipython-input-15-d18f0759e382>", line 1
#     *Array API*
#            ^
# SyntaxError: invalid syntax

# %%
class MyArray:

    def __init__(self,n):
        self.data = [None] * n
        self.len = n

    def __getitem__(self, idx): #O(1)
        """Implements `x = self[idx]`"""
        assert(isinstance(idx, int) and self.len > idx)
        return self.data[idx]

    def __setitem__(self, idx, value): #O(1)
        """Implements `self[idx] = x`"""
        assert(isinstance(idx, int) and self.len > idx)
        self.data[idx] = value

    def __len__(self):
        """Implements `len(self)`"""
        return self.len

    def __repr__(self):
        """Supports inspection"""
        return "[" + ",".join([str(x) for x in self.data]) + "]"

# %%
x = MyArray(3)
x[0] = 'a'
x[1] = 'b'
x[2] = 'c'
x[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-caa6ce6f5a32> in <module>
# ----> 1 x = MyArray(3)
#       2 x[0] = 'a'
#       3 x[1] = 'b'
#       4 x[2] = 'c'
#       5 x[1]
#
# NameError: name 'MyArray' is not defined

# %%
class MyActualArrayList:
    def __init__(self, n=10): # can change up the length of the initial array created --> changes time complexity for appending. Don't have to copy for the first 10. 
        self.data = MyArray(n)
        self.len = 0

    def append(self, value): #O(n) 
        if len(self.data) <= self.len:
            newarray = MyArray(2 * len(self.data)) #n
            for i in range(0, self.len):     #n
                newarray[i] = self.data[i]   #n 
            newarray[self.len] = value       #1 ##could add 10 at a time --> O(n^2)/10

        self.data = newarray             #1
        self.len += 1                    #1

    def __getitem__(self, idx):
        """Implements `x = self[idx]`"""
        assert(isinstance(idx, int) and idx<self.len)
        self.data[idx]

    def __setitem__(self, idx, value):
        """Implements `self[idx] = x`"""
        assert(isinstance(idx, int) and idx<self.len)
        self.data[idx] = value

    def __delitem__(self, idx):
        """Implements `del self[idx]`"""
        assert(isinstance(idx, int) and idx < self.len)
        for i in range(idx+1, self.len):
            self.data[i-1] = self.data[i] #shifting elements to the left
        #newarray = MyArray(self.len - 1)
        #for i in range(0, len(self.data) -1):
        #    newarray[i] = self.data[i]
        #self.data = newarray
        self.len += -1
        

    def __len__(self):
        """Implements `len(self)`"""
        return len(self.data)

    def __repr__(self):
        """Supports inspection"""
        return self.data.data[0:self.len].__repr__()

# %%
x = MyActualArrayList()
x.append(1)
x.append(2)
x.append(3)
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-90c943a716e7> in <module>
# ----> 1 x = MyActualArrayList()
#       2 x.append(1)
#       3 x.append(2)
#       4 x.append(3)
#       5 x
#
# <ipython-input-1-ea1f6c4d1c31> in __init__(self, n)
#       1 class MyActualArrayList:
#       2     def __init__(self, n=10): # can change up the length of the initial array created --> changes time complexity for appending. Don't have to copy for the first 10.
# ----> 3         self.data = MyArray(n)
#       4         self.len = 0
#       5
#
# NameError: name 'MyArray' is not defined

# %%
l = MyActualArrayList()
n = 10
for i in range (0, n):
    l.append(1)

# %%
l = MyActualArrayList(10000)
n = 10000
for i in range (0, n):
    l[i] = 1
len(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2b3820ffbb09> in <module>
# ----> 1 l = MyActualArrayList(10000)
#       2 n = 10000
#       3 for i in range (0, n):
#       4     l[i] = 1
#       5 len(l)
#
# NameError: name 'MyActualArrayList' is not defined

# %%
NOTES ON RUNTIME COMPLEXITY
- insertion: amortized O(1)
- deletion: O(n)
- access element at position i: O(1)
- length: O(1)
